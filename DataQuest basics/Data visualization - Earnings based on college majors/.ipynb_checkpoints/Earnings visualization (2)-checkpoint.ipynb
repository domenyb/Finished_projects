# %% [markdown]
# This guided project was a visualization project of the Data Scientist path.
# The data is job outcomes of students who graduated between 2010 and 2012, and the original (uncleaned) dataset was released as an American Community Survey.
#
# The questions I shall explore are mainly:
#     - Do students of the more popular majors make more?
#     - Which majors have significant disparities in gender?
#     - Which majors are the most popular overall?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
recent_grads=pd.read_csv("recent-grads.csv")
# %matplotlib inline

# %%
recent_grads.head()#Just let's see the data
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.iloc[0]# Let's see all the variables
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %% [markdown]
# This data seems nice and clean - as the project expects -, so far no issues.
# There is a single row where the number of students is missing, I shall drop that one

# %%
recent_grads.dropna(inplace=True)

# %% [markdown]
# From here I shall use scatter plots to explore relations of separate columns... The relations are chosen by the guide, however, I would probably get to the same result - except in more time, and later through removing the plots that seem to have no meaning at all.
#
# Here the guide requires to plot in separate cells for every plot, I would probably do this as subplots...

# %%
fig, ax=plt.subplots()
ax.scatter(recent_grads.Sample_size, recent_grads.Median)
ax.set_title("Sample size vs. Median income")
ax.set_xlim(-100, 4500 )# -100 So that the dots don't start ON the axis 
ax.set_xlabel("Sample size")
ax.set_ylabel("Median income")

# %%
fig, ax=plt.subplots()
x="Sample_size"
y="Unemployment_rate"# its easier this way tbh...
ax.scatter(recent_grads[x], recent_grads[y])
ax.set_title(x.replace("_", " ") +" vs. "+y.replace("_", " "))
ax.set_xlim(-100, 4500 )# -100 So that the dots don't start ON the axis 
ax.set_xlabel(x.replace("_", " "))
ax.set_ylabel(y.replace("_", " "))

# %%
fig, ax=plt.subplots()
x="Full_time"
y="Median"
ax.scatter(recent_grads[x], recent_grads[y])
ax.set_title(x.replace("_", " ") +" vs. "+y.replace("_", " "))
ax.set_xlim(-100, 27000 )# -100 So that the dots don't start ON the axis 
ax.set_xlabel(x.replace("_", " "))
ax.set_ylabel(y.replace("_", " "))

# %%
fig, ax=plt.subplots()
x="ShareWomen"
y="Unemployment_rate"
ax.scatter(recent_grads[x], recent_grads[y])
ax.set_title(x.replace("_", " ") +" vs. "+y.replace("_", " "))
ax.set_xlim( )# -100 So that the dots don't start ON the axis
ax.set_xlabel(x.replace("_", " "))
ax.set_ylabel(y.replace("_", " "))

# %%
fig, ax=plt.subplots()
x="Men"
y="Median"
ax.scatter(recent_grads[x], recent_grads[y])
ax.set_title(x.replace("_", " ") +" vs. "+y.replace("_", " "))
ax.set_xlim(-5000, 180000)# -5000 So that the dots don't start ON the axis 
ax.set_xlabel(x.replace("_", " "))
ax.set_ylabel(y.replace("_", " "))

# %%
fig, ax=plt.subplots()
x="Women"
y="Median"
ax.scatter(recent_grads[x], recent_grads[y])
ax.set_title(x.replace("_", " ") +" vs. "+y.replace("_", " "))
ax.set_xlim(-500, 34000 )# -500 So that the dots don't start ON the axis 
ax.set_xlabel(x.replace("_", " "))
ax.set_ylabel(y.replace("_", " "))

# %%
fig, ax=plt.subplots()
x="ShareWomen"
y="Median"
ax.scatter(recent_grads[x], recent_grads[y])
ax.set_title(x.replace("_", " ") +" vs. "+y.replace("_", " "))
ax.set_xlim(-.1, 1.2)# negative So that the dots don't start ON the axis 
ax.set_xlabel(x.replace("_", " "))
ax.set_ylabel(y.replace("_", " "))

# %% [markdown]
# From the scatter-plots at first I shall try to clear a few relations before moving forward to look at the distributions in more detail.
#
# The median income is not the highest for the most popular majors - though this effect can be explained if there is an overabundance of those majors already...
#
# On the other hand, the unemployment rate is also relatively low in those areas, and some others have a much higher unemployment rate.
#
# There seems to be an anticorrelation between the amount of women in the majors and the median salary.
#
# A clear link between the amount of full-time workers and the median salary currently can not be estabilished, one would need to dive deeper for that.

# %% [markdown]
# As the next step, I shall look at the distributions of the above used metrics in the form of histograms.
#
# Now I will do this in different cells since the data-ranges (and probably the bins as well) would require special attention.... but the subplots still provide a more compact way to look at it imho...

# %%
metric="Sample_size"
recent_grads[metric].hist(range=[0,3000], bins=20)# I have excluded a single 4000+ major
plt.title("Distribution of "+ metric.replace("_", " "))

# %%
metric="Median"
recent_grads[metric].hist(range=[20000,85000], bins=20)#Once again, I have excluded a single outlier
plt.title("Distribution of "+ metric.replace("_", " "))

# %%
metric="Employed"
recent_grads[metric].hist(range=[0,200000], bins=20)# Once again a single exclusion
# I could probably experiment for even better resolution at the bottom if I suspected this to be a
#very important metric.
plt.title("Distribution of "+ metric.replace("_", " "))

# %%
metric="Full_time"
recent_grads[metric].hist(range=[0,18000], bins=20)# One exclusion for a much better distribution
plt.title("Distribution of "+ metric.replace("_", " "))

# %%
metric="ShareWomen"
recent_grads[metric].hist(bins=10)# This is fine, there isn't much more info
# in using 15-20 bins, the shape of the distribution stays similar.
plt.title("Distribution of "+ metric.replace("_", " "))

# %%
metric="Unemployment_rate"
recent_grads[metric].hist(bins=30)# This is an important metric, I think 30 bins
#could represent it just fine. I have tried 50, but that just introduces "noise"
plt.title("Distribution of "+ metric.replace("_", " "))

# %%
metric="Men"
recent_grads[metric].hist(range=[0,10000], bins=20)# I have excluded some, but this way I have a much better 
#look at the bulk of the sample
plt.title("Distribution of "+ metric.replace("_", " "))

# %%
metric="Women"
recent_grads[metric].hist(range=[0,20000], bins=20)# Interestingly, here I have to make
# the cutoff at twice the same value - but once again, this is a nice insight at the distributions.
plt.title("Distribution of "+ metric.replace("_", " "))

# %% [markdown]
# I think at first glance the most interesting thing to look at is the difference in distribution of men and women.
#
# Men don't really seem to be represented at as high numbers as women, but at the same time women seem to be virtually "absent" from a much higher number of fields than men.

# %% [markdown]
# Scatter matrix plot!
#
# I shall just make this with Samplesize, median, and unemployment rate.
#
# This shouldn't bring new info to the table (all the plots have been made already), but it would be nice to see them altogether.

# %%
pd.plotting.scatter_matrix(recent_grads[["Sample_size", "Median", "Unemployment_rate"]], hist_kwds={"bins":15})
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f21f41ded68>,
# ...
#       dtype=object)

# %% [markdown]
# I still like to customize the ranges, bins etc. a little bit for each separate plot, but this is a neat starting point

# %% [markdown]
# Now I shall look at the first & last 10 rows with bar plots - to explore the percentage of women and the unemployment rate for the same professions.
#
# This basically shows the highest and lowest ranked professions - as the dataframe is ordered by rank...

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate')

# %% [markdown]
# THis is the end of the guided project (these last 4 plots are straight up hideous with these long names to be honest...)
#
# Additional steps could be taken (beyond making the above plots less ugly), such as
